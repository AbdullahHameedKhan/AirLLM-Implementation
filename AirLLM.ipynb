# %%
# !pip install airllm
# Out:
# Collecting airllm
#   Downloading airllm-2.11.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from airllm) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from airllm) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from airllm) (4.57.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from airllm) (1.12.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from airllm) (0.7.0)
# Collecting optimum (from airllm)
#   Downloading optimum-2.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from airllm) (0.36.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from airllm) (1.16.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate->airllm) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate->airllm) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->airllm) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate->airllm) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->airllm) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->airllm) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->airllm) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->airllm) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->airllm) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->airllm) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->airllm) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->airllm) (0.22.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->airllm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->airllm) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->airllm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->airllm) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->airllm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->airllm) (2026.1.4)
# Downloading airllm-2.11.0-py3-none-any.whl (36 kB)
# Downloading optimum-2.1.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: optimum, airllm
# Successfully installed airllm-2.11.0 optimum-2.1.0

# %%
# !pip install "transformers==4.46.0" "optimum==1.25.0" "accelerate" "bitsandbytes"
# Out:
# Collecting transformers==4.46.0
#   Using cached transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
# Collecting optimum==1.25.0
#   Downloading optimum-1.25.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (0.7.0)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.0)
#   Using cached tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.46.0) (4.67.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.12/dist-packages (from optimum==1.25.0) (2.9.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11->optimum==1.25.0) (3.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.46.0) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11->optimum==1.25.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11->optimum==1.25.0) (3.0.3)
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.46.0 at https://files.pythonhosted.org/packages/db/88/1ef8a624a33d7fe460a686b9e0194a7916320fc0d67d4e38e570beeac039/transformers-4.46.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.8.0))
# Reason for being yanked: This version unfortunately does not work with 3.8 but we did not drop the support yet
# Downloading transformers-4.46.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 39.8 MB/s eta 0:00:00
# Downloading optimum-1.25.0-py3-none-any.whl (428 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.2/428.2 kB 15.5 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 12.8 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 74.9 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers, bitsandbytes, optimum
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
#   Attempting uninstall: optimum
#     Found existing installation: optimum 2.1.0
#     Uninstalling optimum-2.1.0:
#       Successfully uninstalled optimum-2.1.0
# Successfully installed bitsandbytes-0.49.1 optimum-1.25.0 tokenizers-0.20.3 transformers-4.46.0

# %%
from airllm import AutoModel

MAX_LENGTH = 128
# could use hugging face model repo id:
model = AutoModel.from_pretrained("JungZoona/T3Q-qwen2.5-14b-v1.0-e3")

# or use model's local path...
#model = AutoModel.from_pretrained("/home/ubuntu/.cache/huggingface/hub/models--garage-bAInd--Platypus2-70B-instruct/snapshots/b585e74bcaae02e52665d9ac6d23f4d0dbc81a0f")
# Out:
# >>>> bitsandbytes installed
# >>>> cache_utils installed
# config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Loading shard 1/6
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.embed_tokens.safetensors
#   2%|▏         | 1/51 [01:27<1:12:43, 87.28s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.0.safetensors
#   4%|▍         | 2/51 [01:50<40:25, 49.49s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.1.safetensors
#   6%|▌         | 3/51 [01:56<23:53, 29.87s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.2.safetensors
#  10%|▉         | 5/51 [03:18<27:19, 35.64s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.3.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.4.safetensors
#  12%|█▏        | 6/51 [03:54<26:47, 35.73s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.5.safetensors
#  14%|█▎        | 7/51 [04:01<19:12, 26.19s/it]
# Loading shard 2/6
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.6.safetensors
#  16%|█▌        | 8/51 [06:31<46:56, 65.50s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.7.safetensors
#  18%|█▊        | 9/51 [06:37<32:52, 46.96s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.8.safetensors
#  20%|█▉        | 10/51 [06:40<22:54, 33.51s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.9.safetensors
#  24%|██▎       | 12/51 [06:55<13:05, 20.14s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.10.safetensors
#  25%|██▌       | 13/51 [06:59<09:46, 15.43s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.11.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.12.safetensors
#  27%|██▋       | 14/51 [07:07<08:06, 13.15s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.13.safetensors
#  29%|██▉       | 15/51 [07:16<07:06, 11.85s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.14.safetensors
#  31%|███▏      | 16/51 [07:21<05:41,  9.74s/it]
# Loading shard 3/6
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.15.safetensors
#  33%|███▎      | 17/51 [08:16<13:12, 23.32s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.16.safetensors
#  35%|███▌      | 18/51 [08:25<10:28, 19.06s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.17.safetensors
#  37%|███▋      | 19/51 [08:35<08:43, 16.37s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.18.safetensors
#  39%|███▉      | 20/51 [08:39<06:37, 12.81s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.19.safetensors
#  41%|████      | 21/51 [08:44<05:05, 10.19s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.20.safetensors
#  43%|████▎     | 22/51 [08:49<04:10,  8.64s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.21.safetensors
#  45%|████▌     | 23/51 [08:54<03:31,  7.55s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.22.safetensors
#  47%|████▋     | 24/51 [08:58<02:55,  6.50s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.23.safetensors
#  49%|████▉     | 25/51 [09:08<03:17,  7.58s/it]
# Loading shard 4/6
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.24.safetensors
#  51%|█████     | 26/51 [09:59<08:37, 20.70s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.25.safetensors
#  55%|█████▍    | 28/51 [10:07<04:36, 12.03s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.26.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.27.safetensors
#  59%|█████▉    | 30/51 [10:30<04:05, 11.70s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.28.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.29.safetensors
#  61%|██████    | 31/51 [10:34<03:09,  9.47s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.30.safetensors
#  63%|██████▎   | 32/51 [10:43<02:54,  9.16s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.31.safetensors
#  65%|██████▍   | 33/51 [10:47<02:18,  7.67s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.32.safetensors
#  67%|██████▋   | 34/51 [10:51<01:52,  6.61s/it]
# Loading shard 5/6
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.33.safetensors
#  69%|██████▊   | 35/51 [11:41<05:16, 19.80s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.34.safetensors
#  71%|███████   | 36/51 [11:51<04:09, 16.66s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.35.safetensors
#  75%|███████▍  | 38/51 [12:02<02:24, 11.09s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.36.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.37.safetensors
#  78%|███████▊  | 40/51 [12:20<01:55, 10.54s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.38.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.39.safetensors
#  80%|████████  | 41/51 [12:25<01:26,  8.69s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.40.safetensors
#  82%|████████▏ | 42/51 [12:37<01:26,  9.65s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.41.safetensors
#  84%|████████▍ | 43/51 [12:41<01:04,  8.12s/it]
# Loading shard 6/6
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/4.73G [00:00<?, ?B/s]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.42.safetensors
#  86%|████████▋ | 44/51 [13:36<02:35, 22.25s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.43.safetensors
#  88%|████████▊ | 45/51 [13:43<01:44, 17.50s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.44.safetensors
#  90%|█████████ | 46/51 [13:47<01:07, 13.52s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.45.safetensors
#  92%|█████████▏| 47/51 [13:51<00:42, 10.66s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.46.safetensors
#  96%|█████████▌| 49/51 [14:07<00:18,  9.46s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.layers.47.safetensors
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/model.norm.safetensors
#  98%|█████████▊| 50/51 [14:07<00:06,  6.76s/it]
# saved as: /root/.cache/huggingface/hub/models--JungZoona--T3Q-qwen2.5-14b-v1.0-e3/snapshots/42e91c593cf7ef7564c3ca014482e120679b01df/splitted_model/lm_head.safetensors
# 100%|██████████| 51/51 [14:20<00:00, 16.87s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly

# %%
input_text = [
        'What is the capital of United States?',
        #'I like',
    ]

input_tokens = model.tokenizer(input_text,
    return_tensors="pt",
    return_attention_mask=False,
    truncation=True,
    max_length=MAX_LENGTH,
    padding=False)

generation_output = model.generate(
    input_tokens['input_ids'].cuda(),
    max_new_tokens=20,
    use_cache=True,
    return_dict_in_generate=True)

output = model.tokenizer.decode(generation_output.sequences[0])

print(output)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0):   2%|▏         | 1/51 [00:17<14:17, 17.15s/it]The attention layers in this model are transitioning from computing the RoPE embeddings internally through `position_ids` (2D tensor with the indexes of the tokens), to using externally computed `position_embeddings` (Tuple of tensors, containing cos and sin). In v4.46 `position_ids` will be removed and `position_embeddings` will be mandatory.
# running layers(cuda:0): 100%|██████████| 51/51 [02:46<00:00,  3.27s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:28<00:00,  2.92s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.94s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.94s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.93s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:30<00:00,  2.95s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:30<00:00,  2.95s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:31<00:00,  2.97s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:30<00:00,  2.96s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.92s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.93s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:31<00:00,  2.96s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.93s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:30<00:00,  2.95s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:31<00:00,  2.96s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:29<00:00,  2.94s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:31<00:00,  2.98s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:32<00:00,  2.98s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:33<00:00,  3.02s/it]
# either BetterTransformer or attn_implementation='sdpa' is available, creating model directly
# running layers(cuda:0): 100%|██████████| 51/51 [02:33<00:00,  3.01s/it]
# What is the capital of United States? The capital of the United States is Washington, D.C. It is located on the Potomac
